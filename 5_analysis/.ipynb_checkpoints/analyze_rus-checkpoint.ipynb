# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import analysis_helpers as ah
import seaborn as sns 
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
df = pd.read_csv('/Users/colinbrochard/DSI_Capstone_local/MtProjRec/2_data/3_rus/rusfiles/rus_master.csv')

# %%
ah.plt_count_hists(df)

# %%
ah.plt_cumsum(df)

# %%
print('Original Matrix Stats')
print('---------------------')
ah.pr_mat_stats(df)
# Out:
# Original Matrix Stats
# ---------------------
# matrix size: 3352747324
# matrix shape: users 85871, routes 39044
# matrix density: 0.00044089156060720785

# %%
print('Thresh 10,10 Matrix Stats')
print('-------------------------')
ah.pr_mat_stats(ah.rus_chop(df,10,10))
# Out:
# Thresh 10,10 Matrix Stats
# -------------------------
# matrix size: 527329536
# matrix shape: users 31488, routes 16747
# matrix density: 0.0022921947614935037

# %%
rus_density_thresh = ah.thresh_density_arr(df,30,30)

# %%
ah.density_heatmap(rus_density_thresh)

# %%
#axes are wrong,liking u10, r15
rus_density_thresh_lim = rus_density_thresh[5:15,5:15]
ah.density_heatmap(rus_density_thresh_lim)

# %%
#fit and plot RMSE?? Other avenues for analysis?

# %%
import surprise
from surprise import AlgoBase, Dataset, evaluate, accuracy, SVD, Reader
from surprise.model_selection import train_test_split

# %%
reader = Reader(line_format='user item rating', sep=',', skip_lines=1)
dataset = Dataset.load_from_df(ah.rus_chop(df,10,10),reader)

# %%
# box plot 5-15 of ratings based on bins of number of ratings.

# %%
# talk to Mike about MOES and MOPS

# take out usersers with 8 or more and look how predictive recommender is.
